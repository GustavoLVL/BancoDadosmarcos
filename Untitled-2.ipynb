# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient("mongodb://root:rootpass@localhost:27017")
print(client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['clinica_veterinaria']
colecao = db['atendimentos']

# %%
dados = [
{"tutor":"Ana","animal":"Cachorro","nome_pet":"Rex1","servico":"Consulta","valor":120,"cidade":"Assis","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Bruno","animal":"Gato","nome_pet":"Mimi2","servico":"Vacinação","valor":95,"cidade":"Assis","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Carlos","animal":"Cachorro","nome_pet":"Thor3","servico":"Banho","valor":60,"cidade":"Assis","data":datetime(2026,3,3),"forma_pagamento":"Dinheiro"},
{"tutor":"Daniela","animal":"Ave","nome_pet":"Piu4","servico":"Exame","valor":180,"cidade":"Assis","data":datetime(2026,3,4),"forma_pagamento":"Cartão"},
{"tutor":"Eduardo","animal":"Gato","nome_pet":"Luna5","servico":"Consulta","valor":130,"cidade":"Assis","data":datetime(2026,3,5),"forma_pagamento":"Pix"},
{"tutor":"Fernanda","animal":"Cachorro","nome_pet":"Bob6","servico":"Vacinação","valor":90,"cidade":"Assis","data":datetime(2026,3,6),"forma_pagamento":"Dinheiro"},
{"tutor":"Gabriel","animal":"Coelho","nome_pet":"Pompom7","servico":"Consulta","valor":110,"cidade":"Assis","data":datetime(2026,3,7),"forma_pagamento":"Pix"},
{"tutor":"Helena","animal":"Cachorro","nome_pet":"Mel8","servico":"Cirurgia","valor":820,"cidade":"Assis","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Igor","animal":"Gato","nome_pet":"Simba9","servico":"Banho","valor":55,"cidade":"Assis","data":datetime(2026,3,9),"forma_pagamento":"Cartão"},
{"tutor":"Juliana","animal":"Cachorro","nome_pet":"Nina10","servico":"Consulta","valor":125,"cidade":"Assis","data":datetime(2026,3,10),"forma_pagamento":"Pix"},
{"tutor":"Lucas","animal":"Ave","nome_pet":"Sky11","servico":"Exame","valor":200,"cidade":"Assis","data":datetime(2026,3,11),"forma_pagamento":"Cartão"},
{"tutor":"Mariana","animal":"Gato","nome_pet":"Lili12","servico":"Consulta","valor":135,"cidade":"Assis","data":datetime(2026,3,12),"forma_pagamento":"Pix"},
{"tutor":"Nicolas","animal":"Cachorro","nome_pet":"Bolt13","servico":"Vacinação","valor":100,"cidade":"Assis","data":datetime(2026,3,13),"forma_pagamento":"Dinheiro"},
{"tutor":"Patricia","animal":"Cachorro","nome_pet":"Max14","servico":"Consulta","valor":140,"cidade":"Ourinhos","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Rafael","animal":"Gato","nome_pet":"Mia15","servico":"Banho","valor":65,"cidade":"Ourinhos","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Sofia","animal":"Cachorro","nome_pet":"Luna16","servico":"Cirurgia","valor":900,"cidade":"Ourinhos","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Thiago","animal":"Ave","nome_pet":"Blue17","servico":"Exame","valor":170,"cidade":"Ourinhos","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Vanessa","animal":"Gato","nome_pet":"Nino18","servico":"Consulta","valor":125,"cidade":"Ourinhos","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"William","animal":"Cachorro","nome_pet":"Thor19","servico":"Vacinação","valor":95,"cidade":"Ourinhos","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Beatriz","animal":"Coelho","nome_pet":"Fluffy20","servico":"Consulta","valor":115,"cidade":"Ourinhos","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Caio","animal":"Cachorro","nome_pet":"Spike21","servico":"Banho","valor":70,"cidade":"Ourinhos","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Diego","animal":"Gato","nome_pet":"Tom22","servico":"Consulta","valor":135,"cidade":"Ourinhos","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Elisa","animal":"Cachorro","nome_pet":"Mel23","servico":"Exame","valor":210,"cidade":"Ourinhos","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Felipe","animal":"Ave","nome_pet":"Kiwi24","servico":"Consulta","valor":120,"cidade":"Ourinhos","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Gisele","animal":"Gato","nome_pet":"Nina25","servico":"Vacinação","valor":85,"cidade":"Ourinhos","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Hugo","animal":"Cachorro","nome_pet":"Rex26","servico":"Consulta","valor":150,"cidade":"Ourinhos","data":datetime(2026,3,13),"forma_pagamento":"Cartão"},
{"tutor":"Iris","animal":"Cachorro","nome_pet":"Bob27","servico":"Consulta","valor":110,"cidade":"Pompeia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Joao","animal":"Gato","nome_pet":"Luna28","servico":"Banho","valor":60,"cidade":"Pompeia","data":datetime(2026,3,2),"forma_pagamento":"Dinheiro"},
{"tutor":"Karen","animal":"Cachorro","nome_pet":"Thor29","servico":"Cirurgia","valor":780,"cidade":"Pompeia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Leo","animal":"Ave","nome_pet":"Sky30","servico":"Exame","valor":160,"cidade":"Pompeia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Marta","animal":"Gato","nome_pet":"Mimi31","servico":"Consulta","valor":120,"cidade":"Pompeia","data":datetime(2026,3,5),"forma_pagamento":"Cartão"},
{"tutor":"Nelson","animal":"Cachorro","nome_pet":"Max32","servico":"Vacinação","valor":90,"cidade":"Pompeia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Olga","animal":"Coelho","nome_pet":"Pompom33","servico":"Consulta","valor":105,"cidade":"Pompeia","data":datetime(2026,3,7),"forma_pagamento":"Dinheiro"},
{"tutor":"Paulo","animal":"Cachorro","nome_pet":"Bolt34","servico":"Banho","valor":75,"cidade":"Pompeia","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Quezia","animal":"Gato","nome_pet":"Simba35","servico":"Consulta","valor":130,"cidade":"Pompeia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Renato","animal":"Cachorro","nome_pet":"Nina36","servico":"Exame","valor":190,"cidade":"Pompeia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Sara","animal":"Ave","nome_pet":"Blue37","servico":"Consulta","valor":115,"cidade":"Pompeia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Tiago","animal":"Gato","nome_pet":"Lili38","servico":"Vacinação","valor":85,"cidade":"Pompeia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Ursula","animal":"Cachorro","nome_pet":"Rex39","servico":"Consulta","valor":145,"cidade":"Marilia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Vitor","animal":"Gato","nome_pet":"Mia40","servico":"Banho","valor":70,"cidade":"Marilia","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Wesley","animal":"Cachorro","nome_pet":"Thor41","servico":"Cirurgia","valor":870,"cidade":"Marilia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Xuxa","animal":"Ave","nome_pet":"Piu42","servico":"Exame","valor":175,"cidade":"Marilia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Yara","animal":"Gato","nome_pet":"Luna43","servico":"Consulta","valor":135,"cidade":"Marilia","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"Zeca","animal":"Cachorro","nome_pet":"Bob44","servico":"Vacinação","valor":100,"cidade":"Marilia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Aline","animal":"Coelho","nome_pet":"Fluffy45","servico":"Consulta","valor":120,"cidade":"Marilia","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Bruna","animal":"Cachorro","nome_pet":"Spike46","servico":"Banho","valor":80,"cidade":"Marilia","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Cesar","animal":"Gato","nome_pet":"Tom47","servico":"Consulta","valor":140,"cidade":"Marilia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Dora","animal":"Cachorro","nome_pet":"Mel48","servico":"Exame","valor":220,"cidade":"Marilia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Enzo","animal":"Ave","nome_pet":"Kiwi49","servico":"Consulta","valor":130,"cidade":"Marilia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Fabio","animal":"Gato","nome_pet":"Nina50","servico":"Vacinação","valor":90,"cidade":"Marilia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c336ebebd62c4c6e6e9dcb'), ObjectId('69c336ebebd62c4c6e6e9dcc'), ObjectId('69c336ebebd62c4c6e6e9dcd'), ObjectId('69c336ebebd62c4c6e6e9dce'), ObjectId('69c336ebebd62c4c6e6e9dcf'), ObjectId('69c336ebebd62c4c6e6e9dd0'), ObjectId('69c336ebebd62c4c6e6e9dd1'), ObjectId('69c336ebebd62c4c6e6e9dd2'), ObjectId('69c336ebebd62c4c6e6e9dd3'), ObjectId('69c336ebebd62c4c6e6e9dd4'), ObjectId('69c336ebebd62c4c6e6e9dd5'), ObjectId('69c336ebebd62c4c6e6e9dd6'), ObjectId('69c336ebebd62c4c6e6e9dd7'), ObjectId('69c336ebebd62c4c6e6e9dd8'), ObjectId('69c336ebebd62c4c6e6e9dd9'), ObjectId('69c336ebebd62c4c6e6e9dda'), ObjectId('69c336ebebd62c4c6e6e9ddb'), ObjectId('69c336ebebd62c4c6e6e9ddc'), ObjectId('69c336ebebd62c4c6e6e9ddd'), ObjectId('69c336ebebd62c4c6e6e9dde'), ObjectId('69c336ebebd62c4c6e6e9ddf'), ObjectId('69c336ebebd62c4c6e6e9de0'), ObjectId('69c336ebebd62c4c6e6e9de1'), ObjectId('69c336ebebd62c4c6e6e9de2'), ObjectId('69c336ebebd62c4c6e6e9de3'), ObjectId('69c336ebebd62c4c6e6e9de4'), ObjectId('69c336ebebd62c4c6e6e9de5'), ObjectId('69c336ebebd62c4c6e6e9de6'), ObjectId('69c336ebebd62c4c6e6e9de7'), ObjectId('69c336ebebd62c4c6e6e9de8'), ObjectId('69c336ebebd62c4c6e6e9de9'), ObjectId('69c336ebebd62c4c6e6e9dea'), ObjectId('69c336ebebd62c4c6e6e9deb'), ObjectId('69c336ebebd62c4c6e6e9dec'), ObjectId('69c336ebebd62c4c6e6e9ded'), ObjectId('69c336ebebd62c4c6e6e9dee'), ObjectId('69c336ebebd62c4c6e6e9def'), ObjectId('69c336ebebd62c4c6e6e9df0'), ObjectId('69c336ebebd62c4c6e6e9df1'), ObjectId('69c336ebebd62c4c6e6e9df2'), ObjectId('69c336ebebd62c4c6e6e9df3'), ObjectId('69c336ebebd62c4c6e6e9df4'), ObjectId('69c336ebebd62c4c6e6e9df5'), ObjectId('69c336ebebd62c4c6e6e9df6'), ObjectId('69c336ebebd62c4c6e6e9df7'), ObjectId('69c336ebebd62c4c6e6e9df8'), ObjectId('69c336ebebd62c4c6e6e9df9'), ObjectId('69c336ebebd62c4c6e6e9dfa'), ObjectId('69c336ebebd62c4c6e6e9dfb'), ObjectId('69c336ebebd62c4c6e6e9dfc')], acknowledged=True)

# %%
resultado_valor = list(
    colecao.find({"valor": {"$gte": 90, "$lte": 200}})
)

display(resultado_valor)
# Out:
# [{'_id': ObjectId('69c336ebebd62c4c6e6e9dcb'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dcc'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dce'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dcf'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd0'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd1'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd4'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd5'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd6'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd7'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dd8'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9ddb'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9ddc'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9ddd'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dde'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9de0'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9de2'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9de4'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9de5'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9de8'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9de9'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dea'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9deb'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9ded'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dee'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9def'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9df1'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9df4'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9df5'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9df6'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9df7'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9df9'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dfb'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c336ebebd62c4c6e6e9dfc'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %%
df = pd.DataFrame(resultado_valor)


if "_id" in df.columns:
    df = df.drop(columns=["_id"])

print(df)
# Out:
#        tutor    animal  nome_pet    servico  valor    cidade       data  \
# 0        Ana  Cachorro      Rex1   Consulta    120     Assis 2026-03-01
# 1      Bruno      Gato     Mimi2  Vacinação     95     Assis 2026-03-02
# 2    Daniela       Ave      Piu4      Exame    180     Assis 2026-03-04
# 3    Eduardo      Gato     Luna5   Consulta    130     Assis 2026-03-05
# 4   Fernanda  Cachorro      Bob6  Vacinação     90     Assis 2026-03-06
# 5    Gabriel    Coelho   Pompom7   Consulta    110     Assis 2026-03-07
# 6    Juliana  Cachorro    Nina10   Consulta    125     Assis 2026-03-10
# 7      Lucas       Ave     Sky11      Exame    200     Assis 2026-03-11
# 8    Mariana      Gato    Lili12   Consulta    135     Assis 2026-03-12
# 9    Nicolas  Cachorro    Bolt13  Vacinação    100     Assis 2026-03-13
# 10  Patricia  Cachorro     Max14   Consulta    140  Ourinhos 2026-03-01
# 11    Thiago       Ave    Blue17      Exame    170  Ourinhos 2026-03-04
# 12   Vanessa      Gato    Nino18   Consulta    125  Ourinhos 2026-03-05
# 13   William  Cachorro    Thor19  Vacinação     95  Ourinhos 2026-03-06
# 14   Beatriz    Coelho  Fluffy20   Consulta    115  Ourinhos 2026-03-07
# 15     Diego      Gato     Tom22   Consulta    135  Ourinhos 2026-03-09
# 16    Felipe       Ave    Kiwi24   Consulta    120  Ourinhos 2026-03-11
# 17      Hugo  Cachorro     Rex26   Consulta    150  Ourinhos 2026-03-13
# 18      Iris  Cachorro     Bob27   Consulta    110   Pompeia 2026-03-01
# 19       Leo       Ave     Sky30      Exame    160   Pompeia 2026-03-04
# 20     Marta      Gato    Mimi31   Consulta    120   Pompeia 2026-03-05
# 21    Nelson  Cachorro     Max32  Vacinação     90   Pompeia 2026-03-06
# 22      Olga    Coelho  Pompom33   Consulta    105   Pompeia 2026-03-07
# 23    Quezia      Gato   Simba35   Consulta    130   Pompeia 2026-03-09
# 24    Renato  Cachorro    Nina36      Exame    190   Pompeia 2026-03-10
# 25      Sara       Ave    Blue37   Consulta    115   Pompeia 2026-03-11
# 26    Ursula  Cachorro     Rex39   Consulta    145   Marilia 2026-03-01
# 27      Xuxa       Ave     Piu42      Exame    175   Marilia 2026-03-04
# 28      Yara      Gato    Luna43   Consulta    135   Marilia 2026-03-05
# 29      Zeca  Cachorro     Bob44  Vacinação    100   Marilia 2026-03-06
# 30     Aline    Coelho  Fluffy45   Consulta    120   Marilia 2026-03-07
# 31     Cesar      Gato     Tom47   Consulta    140   Marilia 2026-03-09
# 32      Enzo       Ave    Kiwi49   Consulta    130   Marilia 2026-03-11
# 33     Fabio      Gato    Nina50  Vacinação     90   Marilia 2026-03-12
#
#    forma_pagamento
# 0              Pix
# 1           Cartão
# 2           Cartão
# 3              Pix
# 4         Dinheiro
# 5              Pix
# 6              Pix
# 7           Cartão
# 8              Pix
# 9         Dinheiro
# 10             Pix
# 11             Pix
# 12        Dinheiro
# 13             Pix
# 14          Cartão
# 15             Pix
# 16             Pix
# 17          Cartão
# 18             Pix
# 19             Pix
# 20          Cartão
# 21             Pix
# 22        Dinheiro
# 23             Pix
# 24          Cartão
# 25             Pix
# 26             Pix
# 27             Pix
# 28        Dinheiro
# 29             Pix
# 30          Cartão
# 31             Pix
# 32             Pix
# 33        Dinheiro

# %%
valores_nulos = df.isnull().sum()
print(valores_nulos)
# Out:
# tutor              0
# animal             0
# nome_pet           0
# servico            0
# valor              0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
faturamento_total = df["valor"].sum()
print(faturamento_total)
# Out:
# 4390

# %%
faturamento_cidade = df.groupby("cidade")["valor"].sum()
print(faturamento_cidade)
# Out:
# cidade
# Assis       1285
# Marilia     1035
# Ourinhos    1050
# Pompeia     1020
# Name: valor, dtype: int64

# %%
faturamento_servico = df.groupby("servico")["valor"].sum()
print(faturamento_servico)
# Out:
# servico
# Consulta     2655
# Exame        1075
# Vacinação     660
# Name: valor, dtype: int64

# %%
ticket_medio = df["valor"].mean()
print(ticket_medio)
# Out:
# 129.11764705882354

# %%
df = pd.DataFrame(resultado_valor)

# %%
valores_nulos = df.isnull().sum()
print(valores_nulos)
# Out:
# tutor              0
# animal             0
# nome_pet           0
# servico            0
# valor              0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
top_3_atendimentos = df.nlargest(3, "valor").to_dict(orient="records")

relatorio = {
    "data_geracao": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "faturamento_total": float(df["valor"].sum()),
    "faturamento_por_cidade": df.groupby("cidade")["valor"].sum().to_dict(),
    "faturamento_por_servico": df.groupby("servico")["valor"].sum().to_dict(),
    "ticket_medio_geral": float(df["valor"].mean()),
    "ticket_medio_por_cidade": ticket_medio_por_cidade,
    "servico_mais_lucrativo": df.groupby("servico")["valor"].sum().idxmax(),
    "cidade_maior_faturamento": df.groupby("cidade")["valor"].sum().idxmax(),
    "top_3_atendimentos": top_3_atendimentos
}

# %%
db["relatorios"].insert_one(relatorio)
print(relatorio)
# Out:
# {'data_geracao': '2026-03-25 01:39:38', 'faturamento_total': 4390.0, 'faturamento_por_cidade': {'Assis': 1285, 'Marilia': 1035, 'Ourinhos': 1050, 'Pompeia': 1020}, 'faturamento_por_servico': {'Consulta': 2655, 'Exame': 1075, 'Vacinação': 660}, 'ticket_medio_geral': 129.11764705882354, 'ticket_medio_por_cidade': {'Assis': 128.5, 'Marilia': 129.375, 'Ourinhos': 131.25, 'Pompeia': 127.5}, 'servico_mais_lucrativo': 'Consulta', 'cidade_maior_faturamento': 'Assis', 'top_3_atendimentos': [{'tutor': 'Lucas', 'animal': 'Ave', 'nome_pet': 'Sky11', 'servico': 'Exame', 'valor': 200, 'cidade': 'Assis', 'data': Timestamp('2026-03-11 00:00:00'), 'forma_pagamento': 'Cartão'}, {'tutor': 'Renato', 'animal': 'Cachorro', 'nome_pet': 'Nina36', 'servico': 'Exame', 'valor': 190, 'cidade': 'Pompeia', 'data': Timestamp('2026-03-10 00:00:00'), 'forma_pagamento': 'Cartão'}, {'tutor': 'Daniela', 'animal': 'Ave', 'nome_pet': 'Piu4', 'servico': 'Exame', 'valor': 180, 'cidade': 'Assis', 'data': Timestamp('2026-03-04 00:00:00'), 'forma_pagamento': 'Cartão'}], '_id': ObjectId('69c33ceaebd62c4c6e6e9dff')}

# %%
ticket_medio_por_cidade = df.groupby("cidade")["valor"].mean().to_dict()

# %%
ticket_medio_por_cidade = df.groupby("cidade")["valor"].mean().to_dict()
print(ticket_medio_por_cidade)
# Out:
# {'Assis': 128.5, 'Marilia': 129.375, 'Ourinhos': 131.25, 'Pompeia': 127.5}
